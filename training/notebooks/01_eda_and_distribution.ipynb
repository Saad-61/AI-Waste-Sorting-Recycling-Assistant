# %% [markdown]
# # Waste Classification Dataset - Exploratory Data Analysis
# Analyzes class distributions, bounding box aspects, and image properties.

# %%
import os
import glob
from pathlib import Path
import yaml

DATA_YAML = Path('../dataset/data.yaml')
with open(DATA_YAML, 'r') as f:
    config = yaml.safe_load(f)
print('Config classes:', config['names'])
